# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

'A program used to get GPS information in picture'
__author__ = 'Albert Yang'

import exifread
import re

def FindGPSTime(filePath):
    GPS={}
    Data=""
    f=open(filePath,'rb')
    tags=exifread.process_file(f)
    #print("f:",f.read())
    #print("tags:",tags)
    #for key in tags:
    #    print(key)

    for tag,value in tags.items():
        if re.match('GPS GPSLatitudeRef',tag):
            GPS['GPSLatitudeRef(纬度标识)']=str(value)
        elif re.match('GPS GPSLongitudeRef',tag):
            GPS['GPSLongitudeRef(经度标识)']=str(value)
        elif re.match('GPS GPSAltitudeRef',tag):
            GPS['GPSAltitudeRef(高度标识)']=str(value)
        elif re.match('GPS GPSLatitude',tag):
            try:
                match_result=re.match('\[(\w*), (\w*), (\w.*)/(\w.*)\]',str(value)).groups()   #匹配临近的字符
                GPS['GPSLatitude(纬度)']=int(match_result[0]),int(match_result[1]),int(match_result[2])/int(match_result[3])
            except:
                GPS['GPSLatitude(纬度)']=str(value)
        elif re.match('GPS GPSLongitude',tag):
            try:
                match_result=re.match('\[(\w*), (\w*), (\w.*)/(\w.*)\]',str(value)).groups()
                GPS['GPSLongitude(经度)']=[int(match_result[0]),int(match_result[1]),int(match_result[2])/int(match_result[3])]
            except:
                GPS['GPSLongitude(经度)']=str(value)
        elif re.match('GPS GPSAltitude',tag):
            GPS['GPSAltitude(高度)']=str(value)
        elif re.match('Image DateTime',tag):
            Data=str(value)
    return {'GPS 信息':GPS,'时间信息':Data}
    #http: // www.gpsspg.com / maps.htm

if __name__=='__main__':
    print(FindGPSTime("./data/ltb.jpg"))
# Out:
# {'GPS 信息': {'GPSLatitudeRef(纬度标识)': 'N', 'GPSLatitude(纬度)': (31, 17, 56.65), 'GPSLongitudeRef(经度标识)': 'E', 'GPSLongitude(经度)': [121, 30, 57.68], 'GPSAltitudeRef(高度标识)': '0', 'GPSAltitude(高度)': '1330185/65536'}, '时间信息': '2019:10:20 12:55:18'}

# %%
# Open image file for reading (binary mode)
f = open("./data/ltb.jpg", 'rb')

# Return Exif tags
tags = exifread.process_file(f)

#打印照片其中一些信息
print('拍摄时间：', tags['EXIF DateTimeOriginal'])
print('照相机制造商：', tags['Image Make'])
print('照相机型号：', tags['Image Model'])
print('照片尺寸：', tags['EXIF ExifImageWidth'], tags['EXIF ExifImageLength'])
# Out:
# 拍摄时间： 2019:10:20 12:55:18
# 照相机制造商： Apple
# 照相机型号： iPhone 6s
# 照片尺寸： 4032 3024

# %%
#打印所有照片信息
for tag in tags.keys():    
    print("Key: {}, value {}".format(tag, tags[tag]))
# Out:
# Key: Image Make, value Apple
# Key: Image Model, value iPhone 6s
# Key: Image Orientation, value Rotated 90 CW
# Key: Image XResolution, value 72
# Key: Image YResolution, value 72
# Key: Image ResolutionUnit, value Pixels/Inch
# Key: Image Software, value 13.1.2
# Key: Image DateTime, value 2019:10:20 12:55:18
# Key: Image YCbCrPositioning, value Centered
# Key: Image ExifOffset, value 206
# Key: GPS GPSLatitudeRef, value N
# Key: GPS GPSLatitude, value [31, 17, 1133/20]
# Key: GPS GPSLongitudeRef, value E
# Key: GPS GPSLongitude, value [121, 30, 1442/25]
# Key: GPS GPSAltitudeRef, value 0
# Key: GPS GPSAltitude, value 1330185/65536
# Key: GPS GPSSpeedRef, value K
# Key: GPS GPSSpeed, value 0
# Key: GPS GPSImgDirectionRef, value T
# Key: GPS GPSImgDirection, value 664291/2543
# Key: GPS GPSDestBearingRef, value T
# Key: GPS GPSDestBearing, value 664291/2543
# Key: GPS GPSDate, value 2019:10:20
# Key: GPS Tag 0x001F, value 65
# Key: Image GPSInfo, value 1902
# Key: Thumbnail Compression, value JPEG (old-style)
# Key: Thumbnail XResolution, value 72
# Key: Thumbnail YResolution, value 72
# Key: Thumbnail ResolutionUnit, value Pixels/Inch
# Key: Thumbnail JPEGInterchangeFormat, value 2270
# Key: Thumbnail JPEGInterchangeFormatLength, value 13851
# Key: EXIF ExposureTime, value 1/33
# Key: EXIF FNumber, value 11/5
# Key: EXIF ExposureProgram, value Program Normal
# Key: EXIF ISOSpeedRatings, value 64
# Key: EXIF ExifVersion, value 0231
# Key: EXIF DateTimeOriginal, value 2019:10:20 12:55:18
# Key: EXIF DateTimeDigitized, value 2019:10:20 12:55:18
# Key: EXIF Tag 0x9010, value +08:00
# Key: EXIF Tag 0x9011, value +08:00
# Key: EXIF Tag 0x9012, value +08:00
# Key: EXIF ComponentsConfiguration, value YCbCr
# Key: EXIF ShutterSpeedValue, value 69421/13721
# Key: EXIF ApertureValue, value 193685/85136
# Key: EXIF BrightnessValue, value 78693/26243
# Key: EXIF ExposureBiasValue, value 0
# Key: EXIF MeteringMode, value Pattern
# Key: EXIF Flash, value Flash did not fire, compulsory flash mode
# Key: EXIF FocalLength, value 83/20
# Key: EXIF SubjectArea, value [2015, 1511, 2217, 1330]
# Key: EXIF MakerNote, value [65, 112, 112, 108, 101, 32, 105, 79, 83, 0, 0, 1, 77, 77, 0, 20, 0, 1, 0, 9, ... ]
# Key: EXIF SubSecTimeOriginal, value 838
# Key: EXIF SubSecTimeDigitized, value 838
# Key: EXIF FlashPixVersion, value 0100
# Key: EXIF ColorSpace, value sRGB
# Key: EXIF ExifImageWidth, value 4032
# Key: EXIF ExifImageLength, value 3024
# Key: EXIF SensingMethod, value One-chip color area
# Key: EXIF SceneType, value Directly Photographed
# Key: EXIF ExposureMode, value Auto Exposure
# Key: EXIF WhiteBalance, value Auto
# Key: EXIF FocalLengthIn35mmFilm, value 29
# Key: EXIF SceneCaptureType, value Standard
# Key: EXIF LensSpecification, value [83/20, 83/20, 11/5, 11/5]
# Key: EXIF LensMake, value Apple
# Key: EXIF LensModel, value iPhone 6s back camera 4.15mm f/2.2
# Key: MakerNote Tag 0x0001, value 11
# Key: MakerNote Tag 0x0002, value [114, 0, 144, 0, 189, 0, 205, 0, 171, 1, 5, 1, 73, 0, 14, 0, 13, 0, 13, 0, ... ]
# Key: MakerNote Tag 0x0003, value [6, 7, 8, 85, 102, 108, 97, 103, 115, 85, 118, 97, 108, 117, 101, 89, 116, 105, 109, 101, ... ]
# Key: MakerNote Tag 0x0004, value 1
# Key: MakerNote Tag 0x0005, value 143
# Key: MakerNote Tag 0x0006, value 148
# Key: MakerNote Tag 0x0007, value 1
# Key: MakerNote Tag 0x0008, value [-944373761/-1016070144, 1827620164/842483255, 1110912310/1144467501]
# Key: MakerNote Tag 0x0009, value 4371
# Key: MakerNote Tag 0x000E, value 0
# Key: MakerNote Tag 0x0011, value 4723-9E01-CA65BA310AB6
# Key: MakerNote Tag 0x0014, value 4
# Key: MakerNote Tag 0x0017, value 0
# Key: MakerNote Tag 0x0019, value 0
# Key: MakerNote Tag 0x001F, value 0
# Key: MakerNote Tag 0x0020, value 4851-8969-F32D8776380F
# Key: MakerNote Tag 0x0025, value 0
# Key: MakerNote Tag 0x0026, value 0
# Key: MakerNote Tag 0x0027, value 876162354/1178875949
# Key: MakerNote Tag 0x002B, value 4EC3-8A7C-4D471A339CF5
# Key: JPEGThumbnail, value b'\xff\xd8\xff\xdb\x00\x84\x00\x01\x01\x01\x01\x01\x01\x02\x01\x01\x02\x03\x02\x02\x02\x03\x04\x03\x03\x03\x03\x04\x05\x04\x04\x04\x04\x04\x05\x06\x05\x05\x05\x05\x05\x05\x06\x06\x06\x06\x06\x06\x06\x06\x07\x07\x07\x07\x07\x07\x08\x08\x08\x08\x08\t\t\t\t\t\t\t\t\t\t\x01\x01\x01\x01\x02\x02\x02\x04\x02\x02\x04\t\x06\x05\x06\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\xff\xdd\x00\x04\x00\n\xff\xc0\x00\x11\x08\x00x\x00\xa0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x01\xa2\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfeg\xbc\x15~/o^8\x97\x97V\xcbD\x088!\xb2\x0e\xccp{\xe4\xd7\xaf\xf8j?3]\xb6\x81\xe3U\x95\xa7E\x8d\x9c\xa4\x7f9p\x07\xce\xdfw\x9ew\x121\xc9\'\x8a\xfc\xdd\xf0\xf7\x8a|I\xa5j\xb0\xcd\xab\x99Z\xd8\x1c\xb8UP\xec=\x03\x1cc>\xb5\xf5G\xc3\x9f\x8c~\x19]N\xebM\xd4umKG\x86m:\xe4\xc1;[\xad\xda}\xb7(\xd1C*o\x0f\xe4:\x87Vu;\x83\x158\xdb\x9a\xff\x00]\xbc2\xfd\xa0yvE\x82\x96\x1e\xb6\x12\xa2\x95\xbd\xdbY\xc6\xfez\xa7oD~C\x9axc_\x11>zu#\xf9?\x97\xfc9\xfb=\xe3O\xd8\xa7\xe2\x93\xea\xb0\xfc]\xbb\xd74m~\xcb@\x82\x18\xe76\x97\xca\xe4\xa9@\xab\x121,Y\xb7\x91\x82\xb9\x0f\xfc<\x1c\xd7\xe6\x1f\x8at\x0f\x11i>!\x9f\xc33G\xe4]\xe8\xd3+\xdc#ltV8a\xd0\xb2\x9ct<\x9e\xe0\x8a\xf9\xa7^\xf8\x8ds%\xf4Z\x8e\x89\xe2\x14\x9a\xe7*\xae\xba|w6\x93(\x00(\xcf\x98\x8a\xbct\x18f\xf4\xe9\xcd~\xa3\xf